# %% [markdown]
# <a href="https://colab.research.google.com/github/rishikumar74/deeplearning/blob/main/NLP_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# ...

# %% [markdown]
# Text preprocessing in NLP
# before training NLP models,we must clean the text
# this process is called TextPreprocessing

# %% [markdown]
# # **Tokenization**

# %%
from nltk.tokenize import word_tokenize
text="I Love learning Natural Lang Processing"
#words tokenizer
tokens=word_tokenize(text)
print(tokens)
#charcter wise tokenizer
char_tokens=list(text)
print(char_tokens)
# Out:
# ['I', 'Love', 'learning', 'Natural', 'Lang', 'Processing']
# ['I', ' ', 'L', 'o', 'v', 'e', ' ', 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g', ' ', 'N', 'a', 't', 'u', 'r', 'a', 'l', ' ', 'L', 'a', 'n', 'g', ' ', 'P', 'r', 'o', 'c', 'e', 's', 's', 'i', 'n', 'g']

# %% [markdown]
# # **LowerCasing**

# %%
text=text.lower()
print(text)
# Out:
# i love learning natural lang processing

# %% [markdown]
# # **StopwordRemoval**
# stop words are common words with little meaning
# eg:is,the,a,an,and,of

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))
print(stop_words)

print("After stopwords Removed")
filtered_tokens=[token for token in tokens if token not in stop_words]
print(filtered_tokens)
# Out:
# {'out', 'mustn', 'having', 'if', "you'd", "didn't", 'haven', "shouldn't", 'why', 'so', 'no', 't', 'again', "they'll", 'and', 'shouldn', "we've", 'its', 'from', 'these', 'themselves', 'this', 'while', "i've", 'ourselves', 'then', 'down', "it's", "it'd", 'their', 'weren', 'than', 'both', "shan't", 'me', 'very', 'not', 'should', 'our', 'all', 'couldn', 'each', 'with', 'an', "aren't", 'hadn', 'm', 'does', 'at', 'only', "she'd", 'through', 'shan', 'wouldn', "you're", 'before', 'have', 'more', 'other', "wouldn't", "she's", "i'm", 'her', 'o', 'herself', 'off', "hadn't", "he'll", 'isn', "he'd", 'mightn', 'there', 'll', 'ma', 'those', 'after', 'she', 'had', "isn't", 'because', "mightn't", 'of', 'too', 'itself', "they're", 'y', 'by', "hasn't", 'or', "don't", 'where', "haven't", "it'll", 'same', 'above', 'hers', 'my', 'did', "weren't", 'can', 'until', 'were', 'but', "i'll", "they've", 'wasn', "needn't", "we'll", 'under', 'when', 'being', 'to', 'yours', 'we', 'do', 'nor', 'into', 're', 'further'
# ...

# %% [markdown]
# # **Remove punctuations**
#
# puncuation removal simplifies text data,streamlining the analysis by reducing the complexitty and varaibility within the data
# eg:hello!!!!!----->hello

# %%
import string
text="Hello!!! Nlp is amazing!!!!"
clean_text=text.translate(str.maketrans('','',string.punctuation))
print(clean_text)

# we can remove punctuations by using regular exprr
from nltk.tokenize import RegexpTokenizer
tokenizer=RegexpTokenizer(r'\w+')
text="this is another !!sample text !!$"
tokens=tokenizer.tokenize(text)
print(tokens)
# Out:
# Hello Nlp is amazing
# ['this', 'is', 'another', 'sample', 'text']

# %% [markdown]
# # **POS Tagging**
# pos tagging=assigning a gramtical label to each word in a sentence
#
# | Tag | Meaning    | Example   |
# | --- | ---------- | --------- |
# | NN  | Noun       | cat, book |
# | VB  | Verb       | run, eat  |
# | JJ  | Adjective  | happy     |
# | RB  | Adverb     | quickly   |
# | PRP | Pronoun    | he, she   |
# | DT  | Determiner | the, a    |
#
# | Word     | Tag | Meaning         |
# | -------- | --- | --------------- |
# | I        | PRP | Pronoun         |
# | love     | VBP | Verb            |
# | learning | VBG | Verb (ing form) |
# | NLP      | NNP | Proper noun     |

# %%
sentence="I Love Learning NLP"
words=nltk.word_tokenize(sentence)
print(words)

pos_tags=nltk.pos_tag(words)
print(pos_tags)
# Out:
# ['I', 'Love', 'Learning', 'NLP']
# [('I', 'PRP'), ('Love', 'VBP'), ('Learning', 'VBG'), ('NLP', 'NNP')]

# %% [markdown]
# # **Stemming**
# stemming reduces words to their root form
# by removing prefixes && suffixes
#
#
# eg:likes--->like
#
# liked-->like
#
#
# likely-->like
#
#
# liking --->like

# %%
from nltk.stem import PorterStemmer
#porter stemmer
porter_stemmer=PorterStemmer()
words=["Running","jumps","liked","running","playing","happily"]
stemmmed_words=[porter_stemmer.stem(word) for word in words]
print("original words:",words)
print("stemmed words:",stemmmed_words)
# Out:
# original words: ['Running', 'jumps', 'liked', 'running', 'playing', 'happily']
# stemmed words: ['run', 'jump', 'like', 'run', 'play', 'happili']

# %%
#snowball stemmer:is a enhanced version of porter stemnmer,supports multiple languages
from nltk.stem import SnowballStemmer
sb=SnowballStemmer(language='english')
words_to_stem=["Running","jumps","liked","running","playing","happily"]
stemmed_words=[sb.stem(word) for word in words_to_stem]
print("original words:",words_to_stem)
print("stemmed words:",stemmmed_words)
# Out:
# original words: ['Running', 'jumps', 'liked', 'running', 'playing', 'happily']
# stemmed words: ['run', 'jump', 'like', 'run', 'play', 'happili']

# %%
#Lancaster Stemmer:more aggressive and faster than other stemmers
from nltk.stem import LancasterStemmer

lc=LancasterStemmer()
words=["Running","jumps","liked","running","playing","happily"]
stemmmed_words=[lc.stem(word) for word in words]
print("original words:",words)
print("stemmed words:",stemmmed_words)
# Out:
# original words: ['Running', 'jumps', 'liked', 'running', 'playing', 'happily']
# stemmed words: ['run', 'jump', 'lik', 'run', 'play', 'happy']

# %% [markdown]
# # **Lemmatization**
# lemmatization produces meaningful root words
#
# eg:
#
# better--->good
#
#
# running-->run
#
# ## **Lemmatization**
#
# Lemmatization produces meaningful root words.
#
# **Example**
#
# better → good
#
# running → run
#
# Lemmatization is an important text pre-processing technique in Natural Language Processing (NLP) that reduces words to their base form known as a "lemma." For example, the lemma of "running" is "run" and "better" becomes "good."
#
# Unlike stemming which simply removes prefixes or suffixes, it considers the word's meaning and part of speech (POS) and ensures that the base form is a valid word. This makes lemmatization more accurate as it avoids generating non-dictionary words.
#
# **Used for:**
#
# Improves accuracy
#
# Reduced Data Redundancy
#
# Better NLP Model Performance

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
print(lemmatizer.lemmatize("better",pos='a'))
print(lemmatizer.lemmatize("running",pos='v'))
print(lemmatizer.lemmatize("kicking",pos='v'))
# Out:
# good
# run
# kick

# %% [markdown]
# ## **Bag of Words (BoW)**
#
# BoW represents text as word frequency vectors.
#
# In Natural Language Processing (NLP) text data needs to be converted into numbers so that machine learning algorithms can understand it. One common method to do this is Bag of Words (BoW) model. It turns text like sentence, paragraph or document into a collection of words and counts how often each word appears but ignoring the order of the words. It does not consider the order of the words or their grammar but focuses on counting how often each word appears in the text.
#
# This makes it useful for tasks like text classification, sentiment analysis and clustering.

# %% [markdown]
# #step1 :preprocessing the Text
# clean the text
# ->convert to lowercase
# ->remove special charectres

# %%
import re
dataset=[]
text=["I Love coding !",
      "I love python$",
      "Python coding is fun"
      ]

for sentence in text:
  sentence=sentence.lower() #lwer case
  sentence=re.sub(r'\W',' ',sentence)   #remove special cahr
  sentence=re.sub(r'\s+',' ',sentence)  #remove erxtra spaces
  dataset.append(sentence)
print(dataset)
# Out:
# ['i love coding ', 'i love python ', 'python coding is fun']

# %%
#step2 :count word freq
from collections import defaultdict
word2count=defaultdict(int)
for sentence in dataset :
  for word in sentence.split():
    word2count[word]+=1
print(word2count)
# Out:
# defaultdict(<class 'int'>, {'i': 2, 'love': 2, 'coding': 2, 'python': 2, 'is': 1, 'fun': 1})

# %% [markdown]
# # **step 3:Selecting Most Frquent Words **
# lets take top 3 words

# %%
import heapq
freq_words=heapq.nlargest(3, word2count, key=word2count.get)
print(freq_words)
# Out:
# ['i', 'love', 'coding']

# %% [markdown]
# Step4 :Build BAg of Words Matrix
#
# now we can create a matrix
#
# rows=senetence
#
#
# columns=frequent words
#
# value=1(present) or 0(abscent)

# %%
x=[]
for sentence in dataset:
  vector=[]
  words=sentence.split()

  for word in freq_words:
    if word in words:
      vector.append(1)
    else:
      vector.append(0)
  x.append(vector)
print(x)
# Out:
# [[1, 1, 1], [1, 1, 0], [0, 0, 1]]

# %% [markdown]
# | sentence               | i | love | coding |
# | ---------------------- | - | ---- | ------ |
# | i love coding          | 1 | 1    | 1      |
# | i love python          | 1 | 1    | 0      |
# | python coding is fun   | 0 | 0    | 1      |

# %% [markdown]
# Key idea
#
# N-grams capture word relationship
#
# BoW-->"love","coding"
#
# Bigram----->"love coding"(more meaning)
#
# # **N-grams**
#
# N-grams capture word sequences.
#
# N-gram is a technique that splits text into sequences of N consecutive words to capture context and word order for machine learning models.
#
# N-gram = group of N consecutive words
#
# 1 word → Unigram
#
# 2 words → Bigram
#
# 3 words → Trigram

# %%
#### **✅ Simple Example**


#### "I love coding"
####🔹 Unigrams (N = 1)
["I", "love", "coding"]
####🔹 Bigrams (N = 2)
["I love", "love coding"]
####🔹 Trigrams (N = 3)
["I love coding"]
# Out:
# ['I love coding']

# %% [markdown]
# # **TF-IDF :(team frequency -inverse Document Frequency)**
# tf-idf gives importance to rare words .it is used to meaasure how imp a word is in a document
